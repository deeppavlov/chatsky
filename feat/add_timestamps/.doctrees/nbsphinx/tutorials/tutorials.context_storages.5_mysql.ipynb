# %% [markdown]
# # 5. MySQL
#
# This is a tutorial on using MySQL.
#
# See [SQLContextStorage](../apiref/chatsky.context_storages.sql.rst#chatsky.context_storages.sql.SQLContextStorage) class
# for storing you users' contexts in SQL databases.
#
# Chatsky uses [sqlalchemy](https://docs.sqlalchemy.org/en/20/)
# and [asyncmy](https://github.com/long2ice/asyncmy)
# libraries for asynchronous access to MySQL DB.

# %%
# installing dependencies
# %pip install -q chatsky[mysql]==0.10.0
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

from chatsky.context_storages import context_storage_factory

from chatsky import Pipeline
from chatsky.utils.testing.common import (
    check_happy_path,
    is_interactive_mode,
)
from chatsky.utils.testing.toy_script import TOY_SCRIPT_KWARGS, HAPPY_PATH

# %%
db_uri = "mysql+asyncmy://{}:{}@localhost:3307/{}".format(
    os.environ["MYSQL_USERNAME"],
    os.environ["MYSQL_PASSWORD"],
    os.environ["MYSQL_DATABASE"],
)
db = context_storage_factory(db_uri)


pipeline = Pipeline(**TOY_SCRIPT_KWARGS, context_storage=db)

# %%
if __name__ == "__main__":
    check_happy_path(pipeline, HAPPY_PATH, printout=True)
    if is_interactive_mode():
        pipeline.run()
# Out:
# USER: text='Hi'
# BOT : text='Hi, how are you?' timestamp='2025-05-16 12:07:58.749099'
# USER: text='i'm fine, how are you?'
# BOT : text='Good. What do you want to talk about?' timestamp='2025-05-16 12:07:58.771755'
# USER: text='Let's talk about music.'
# BOT : text='Sorry, I can not talk about music now.' timestamp='2025-05-16 12:07:58.791965'
# USER: text='Ok, goodbye.'
# BOT : text='bye' timestamp='2025-05-16 12:07:58.811243'
# USER: text='Hi'
# BOT : text='Hi, how are you?' timestamp='2025-05-16 12:07:58.830406'
