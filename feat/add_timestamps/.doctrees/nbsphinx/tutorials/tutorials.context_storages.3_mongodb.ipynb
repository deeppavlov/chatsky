# %% [markdown]
# # 3. MongoDB
#
# This is a tutorial on using MongoDB.
#
# See [MongoContextStorage](../apiref/chatsky.context_storages.mongo.rst#chatsky.context_storages.mongo.MongoContextStorage) class
# for storing you users' contexts in Mongo database.
#
# Chatsky uses [motor](https://motor.readthedocs.io/en/stable/)
# library for asynchronous access to MongoDB.

# %%
# installing dependencies
# %pip install -q chatsky[mongodb]==0.10.0
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

from chatsky.context_storages import context_storage_factory

from chatsky import Pipeline
from chatsky.utils.testing.common import (
    check_happy_path,
    is_interactive_mode,
)
from chatsky.utils.testing.toy_script import TOY_SCRIPT_KWARGS, HAPPY_PATH

# %%
db_uri = "mongodb://{}:{}@localhost:27017/{}".format(
    os.environ["MONGO_INITDB_ROOT_USERNAME"],
    os.environ["MONGO_INITDB_ROOT_PASSWORD"],
    os.environ["MONGO_INITDB_ROOT_USERNAME"],
)
db = context_storage_factory(db_uri)

pipeline = Pipeline(**TOY_SCRIPT_KWARGS, context_storage=db)

# %%
if __name__ == "__main__":
    check_happy_path(pipeline, HAPPY_PATH, printout=True)
    if is_interactive_mode():
        pipeline.run()
# Out:
# USER: text='Hi'
# BOT : text='Hi, how are you?' timestamp='1748431871639190596'
# USER: text='i'm fine, how are you?'
# BOT : text='Good. What do you want to talk about?' timestamp='1748431871651769094'
# USER: text='Let's talk about music.'
# BOT : text='Sorry, I can not talk about music now.' timestamp='1748431871660988460'
# USER: text='Ok, goodbye.'
# BOT : text='bye' timestamp='1748431871670166642'
# USER: text='Hi'
# BOT : text='Hi, how are you?' timestamp='1748431871679407940'
